# %%
import importlib
import datetime as dt

import matplotlib.pyplot as plt
import matplotlib.dates as mdates

import numpy as np

import pandas as pd

from scipy import stats

import plotly.graph_objects as ptly
import plotly.express as px

import waldluft as wl

plt.style.use("janjo-v0-0.mplstyle")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 16
#      13 import plotly.graph_objects as ptly
#      14 import plotly.express as px
# ---> 16 import waldluft as wl
#      18 plt.style.use("janjo-v0-0.mplstyle")
#
# ModuleNotFoundError: No module named 'waldluft'

# %%
importlib.reload(wl)
# Out:
# <module 'waldluft' from '/Users/Janjo/Documents/MEINE DOKUMENTE/Projects/kaltluftstrom/waldluft.py'>

# %%
inst = wl.Timed("raw_data/221218", encoding="iso8859-1")
# Out:
# Successfully imported the following sensor data:
#     WTDL:
#         W6
#         W7
#         W5
#         W1
#         W3
#         W2
#         W9
#         W8
#     SHT:

# %%
inst.plot_temp_time(sensor_manual=["W2"],)

# %%
inst.timeseries["W2_raw"] = inst.timeseries["W2"]

# %%
inst.timeseries["W2"] = inst.timeseries["W2"].loc[
    dt.datetime(2022,1,1,1).strftime('%Y-%m-%d %H:%M:%S.%f')
    :dt.datetime(2022,12,31).strftime('%Y-%m-%d %H:%M:%S.%f')
]
# Out:
# <ipython-input-6-60368374151c>:1: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   inst.timeseries["W2"] = inst.timeseries["W2"].loc[

# %%
inst.timeseries["W1"].shape
# Out:
# (79589, 2)

# %%
inst.timeseries["W2_raw"].shape
# Out:
# (78033, 2)

# %%
inst.timeseries["W2"].shape
# Out:
# (77058, 2)

# %%
inst.plot_temp_time(sensor_manual=["W1", "W2"],)

# %%
inst.timeseries["W2"].rename(columns={"T": "Temperatur [°C]"}).to_csv("raw_data/221218_cleaned/W2_cleaned.csv", sep=";", index=False, encoding="iso8859-1")

# %%
inst_cleaned = wl.Timed("raw_data/221218_cleaned", encoding="iso8859-1")
# Out:
# Successfully imported the following sensor data:
#     WTDL:
#         W6
#         W7
#         W5
#         W1
#         W3
#         W2
#         W9
#         W8
#         W4
#     SHT:

# %%
inst_cleaned.plot_temp_time(
    sensor_manual=["W1", "W2", "W4"],
    title="Datenlücken W2 und W4",
    fig_export=True,
    fig_export_path="graphics_misc",
)
# Out:
# image was saved at graphics_misc/Datenlücken_W2_und_W4_W1W2W4_size-10-6.pdf

# %%
inst_cleaned.plot_temp_time(
    sensor_manual=["W8", "W9"],
    title="Quartier (W8) vs. Wald (W9)",
    fig_export=True,
    fig_export_path="graphics_misc",
)
# Out:
# image was saved at graphics_misc/Quartier_W8_vs._Wald_W9_W8W9_size-10-6.pdf
